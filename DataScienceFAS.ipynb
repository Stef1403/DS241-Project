# %%
import pandas as pd

# %%
data = pd.read_csv("Downloads/SalesDirect.csv")

# %%
data
# Out:
#          Sales Purchase      Month  AgeInMonths  ProfileInMonths Subscribed  \
# 0       519.91      Yes   November          450               22       None
# 1       620.48      Yes      April          511               29       None
# 2       545.22      Yes       July          410               28       None
# 3       438.87      Yes  September          451                1       None
# 4         0.00       No    January          402                7       None
# ...        ...      ...        ...          ...              ...        ...
# 149995  507.73      Yes      March          434               20      Daily
# 149996  465.05      Yes      March          404                7       None
# 149997  530.91      Yes       June          411               31    Monthly
# 149998    0.00       No   February          510               16       None
# 149999    0.00       No   February          424               46       None
#
# ...
